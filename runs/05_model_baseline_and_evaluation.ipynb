# %%
import sys, os
import importlib
import pandas as pd

# %%
sys.path.append(os.path.abspath(".."))

# %%
from src.config import  CLEAN_PARQUET, X_TRAIN_PARQUET, X_TEST_PARQUET, Y_TRAIN_PARQUET, Y_TEST_PARQUET
from src.artifacts import load_df, load_obj

# %%
import src.model_baseline_and_evaluation 
importlib.reload(src.model_baseline_and_evaluation )
from src.model_baseline_and_evaluation import (
    run_baseline_and_evaluation
)

# %%
df = load_df(CLEAN_PARQUET)

# %%
print("After dummies:", df.shape)
print("New columns:", df.columns.tolist())
# Out:
# After dummies: (614, 13)
# New columns: ['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Gender_Male', 'Married_Yes', 'Education_Not Graduate', 'Self_Employed_Yes', 'Property_Area_Semiurban', 'Property_Area_Urban', 'Loan_Status_Y']

# %%
run_baseline_and_evaluation(df, target="Loan_Status_Y")
# Out:
# Logistic Regression
# Accuracy: 0.7886178861788617
# F1 Score: 0.8586956521739131
#               precision    recall  f1-score   support
#
#        False       0.95      0.42      0.58        43
#         True       0.76      0.99      0.86        80
#
#     accuracy                           0.79       123
#    macro avg       0.85      0.70      0.72       123
# weighted avg       0.83      0.79      0.76       123
# SVM (Linear)
# Accuracy: 0.7886178861788617
# F1 Score: 0.8586956521739131
#               precision    recall  f1-score   support
#
#        False       0.95      0.42      0.58        43
#         True       0.76      0.99      0.86        80
#
#     accuracy                           0.79       123
#    macro avg       0.85      0.70      0.72       123
# weighted avg       0.83      0.79      0.76       123
# SVM (RBF)
# Accuracy: 0.6504065040650406
# F1 Score: 0.7881773399014779
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00        43
#         True       0.65      1.00      0.79        80
#
#     accuracy                           0.65       123
#    macro avg       0.33      0.50      0.39       123
# weighted avg       0.42      0.65      0.51       123
# C:\Users\mukil\anaconda3\envs\aiml\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\mukil\anaconda3\envs\aiml\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\mukil\anaconda3\envs\aiml\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# KNN
# Accuracy: 0.5772357723577236
# F1 Score: 0.7204301075268817
#               precision    recall  f1-score   support
#
#        False       0.24      0.09      0.13        43
#         True       0.63      0.84      0.72        80
#
#     accuracy                           0.58       123
#    macro avg       0.43      0.47      0.43       123
# weighted avg       0.49      0.58      0.52       123
# Naive Bayes
# Accuracy: 0.7804878048780488
# F1 Score: 0.8524590163934426
#               precision    recall  f1-score   support
#
#        False       0.90      0.42      0.57        43
#         True       0.76      0.97      0.85        80
#
#     accuracy                           0.78       123
#    macro avg       0.83      0.70      0.71       123
# weighted avg       0.81      0.78      0.75       123
# Decision Tree
# Accuracy: 0.6991869918699187
# F1 Score: 0.7810650887573964
#               precision    recall  f1-score   support
#
#        False       0.59      0.47      0.52        43
#         True       0.74      0.82      0.78        80
#
#     accuracy                           0.70       123
#    macro avg       0.66      0.65      0.65       123
# weighted avg       0.69      0.70      0.69       123
# Random Forest
# Accuracy: 0.7723577235772358
# F1 Score: 0.8461538461538461
#               precision    recall  f1-score   support
#
#        False       0.86      0.42      0.56        43
#         True       0.75      0.96      0.85        80
#
#     accuracy                           0.77       123
#    macro avg       0.81      0.69      0.70       123
# weighted avg       0.79      0.77      0.75       123
# === Model Comparison ===
#                  Model  Accuracy        F1
# 0  Logistic Regression  0.788618  0.858696
# 1         SVM (Linear)  0.788618  0.858696
# 4          Naive Bayes  0.780488  0.852459
# 6        Random Forest  0.772358  0.846154
# 2            SVM (RBF)  0.650407  0.788177
# 5        Decision Tree  0.699187  0.781065
# 3                  KNN  0.577236  0.720430
#                  Model  Accuracy        F1
# 0  Logistic Regression  0.788618  0.858696
# 1         SVM (Linear)  0.788618  0.858696
# 2            SVM (RBF)  0.650407  0.788177
# 3                  KNN  0.577236  0.720430
# 4          Naive Bayes  0.780488  0.852459
# 5        Decision Tree  0.699187  0.781065
# 6        Random Forest  0.772358  0.846154
